# %%
import pandas as pd
import geopandas
import matplotlib.pyplot as plt
df = pd.read_csv('dataset.csv')

#print(df.to_string())

# number of rows
num_rows = df.shape[0]
#print(num_rows)

# number of cols
num_cols = df.shape[1]
#print(num_cols)

NEIGHBORHOODS = geopandas.read_file("https://data.wprdc.org/dataset/e672f13d-71c4-4a66-8f38-710e75ed80a4/resource/c5a93a8e-03d7-4eb3-91a8-c6b7db0fa261/download/pittsburghpaneighborhoods-.zip")
ZIPS =  geopandas.read_file("https://data.wprdc.org/dataset/1a5135de-cabe-4e23-b5e4-b2b8dd733817/resource/ec228c0e-6b1e-4f44-a335-df05546d52ea/download/alcogisallegheny-county-zip-code-boundaries.zip")

neighborhood_counts = df.groupby('neighborhood')['_id'].count()
# Sort the neighborhood_counts DataFrame by count in descending order
neighborhood_counts_sorted = neighborhood_counts.sort_values(ascending=False)

# Print the sorted DataFrame
print("Water fountains by neighborhood (sorted by count):\n")
print(neighborhood_counts_sorted.to_string())

most_dependable_df = df[df['make'] == 'Most Dependable']

print("\n\n\n")

# Group by 'neighborhood' and count the occurrences
neighborhood_counts = most_dependable_df.groupby('neighborhood').size()

# Sort the counts in descending order to get the rank
neighborhood_rank = neighborhood_counts.sort_values(ascending=False)

# Print the ranked neighborhoods
print("Neighborhoods ranked by 'Most Dependable' count:")
print(neighborhood_rank)

neighborhood_counts = df['neighborhood'].value_counts()

# Plotting
plt.figure(figsize=(20, 6))  # Increase the figure width for better spacing
neighborhood_counts.plot(kind='bar', color='skyblue')
plt.title('Number of Times Each Row Corresponds to a Neighborhood')
plt.xlabel('Neighborhood')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right')  # Rotate labels and adjust alignment
plt.subplots_adjust(bottom=0.3)  # Adjust bottom margin to increase space
plt.grid(axis='y', linestyle='--', alpha=0.9)
plt.show()
# Out:
# Water fountains by neighborhood (sorted by count):
#
# neighborhood
# Squirrel Hill South          14
# Highland Park                12
# Allegheny Center              8
# Brookline                     8
# Terrace Village               8
# Bloomfield                    8
# Point Breeze                  7
# Perry North                   7
# Brighton Heights              6
# Spring Hill-City View         6
# Mount Washington              6
# Troy Hill                     6
# East Liberty                  6
# Elliott                       6
# Carrick                       6
# South Side Flats              5
# Morningside                   5
# Beechview                     5
# Shadyside                     5
# Garfield                      4
# Central Business District     4
# North Oakland                 3
# Sheraden                      3
# Perry South                   3
# Polish Hill                   3
# Regent Square                 3
# Lincoln Place                 3
# ...
